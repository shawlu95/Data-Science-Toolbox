# %%
from scipy.stats import shapiro
import numpy as np

# %% [markdown]
# #### Shapiro-Wilk Test
# * Null: sample is drawn from normal distribution.

# %%
# reject null
expo = np.random.exponential(3, 100)
w, p = shapiro(expo)
p
# Out:
# 2.053588410433349e-08

# %%
# cannot reject null
gaus = np.random.normal(3, 1, 100)
w, p = shapiro(gaus)
p
# Out:
# 0.7674536108970642
