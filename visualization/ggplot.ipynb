# %%
from ggplot import *
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %% [markdown]
# ##### Scatter and Line Plot

# %%
x = np.linspace(0, 10, 100)
y = x * 3 + np.random.normal(0, 5, 100)
z = np.array(range(100)) % 2
df = pd.DataFrame({"x" : x, "y" : y, "z" : z})

# %%
g = ggplot(df, aes("x", "y")) \
     + geom_point(color='red') \
     + geom_line(color='red') \
     + ggtitle("title") \
     + xlab("haha") \
     + ylab("good")
print(g)
# Out:
# <ggplot: (293479414)>

# %%
df.head()
# Out:
#          x         y  z
# 0  0.00000 -4.162466  0
# 1  0.10101  9.852455  1
# 2  0.20202  1.036024  0
# 3  0.30303 -1.629940  1
# 4  0.40404  4.609784  0

# %%
plt.figure(figsize=(12, 8))
plt.scatter(x, y)
plt.plot(x, y)

# %% [markdown]
# ##### Density Plot
# * Plot maximum likelihood estimate of a p=0.7 biased coin.
# * Use this plot to turn histogram into density.

# %%
samples = np.random.binomial(n=100, p=0.7, size=10000)
p_mles = samples / 100

# %%
df = pd.DataFrame({"trials" : p_mles})
df.dropna().shape
# Out:
# (10000, 1)

# %%
g = (ggplot(df, aes("trials")) \
     + geom_density(alpha = 0.5) \
     + xlab("Prior") \
     + ylab("Count"))
print(g)
# Out:
# <ggplot: (-9223372036561495969)>
