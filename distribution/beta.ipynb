# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample = np.random.beta(1, 1, 100000)
plt.hist(sample, bins=50)
plt.show()

# %%
sample = np.random.beta(1, 3, 100000)
plt.hist(sample, bins=50)
plt.show()

# %%
sample = np.random.beta(2, 3, 100000)
plt.hist(sample, bins=50)
plt.show()

# %%
sample = np.random.beta(2, 2, 100000)
plt.hist(sample, bins=50)
plt.show()

# %%
sample = np.random.beta(100, 100, 100000)
plt.hist(sample, bins=50)
plt.show()
